# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss=np.loadtxt("../traj/trloss")
lossv=np.loadtxt("../traj/valoss")

# %%
tt=10000
loss[loss>=tt]=tt
plt.plot(loss)
plt.show()
lossv[lossv>=tt]=tt
plt.plot(lossv)
plt.show()

# %%
plt.plot(loss)
plt.plot(lossv)
plt.show()
